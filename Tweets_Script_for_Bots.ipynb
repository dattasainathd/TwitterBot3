# %%
import tweepy
import csv
import time
import pandas

consumer_key = "BYADovvYQhDt8YWSGw57HqcZO"
consumer_secret = "CbCfzNaGf7BuH5nTksUZUo7VWlnhJEkmOiKFqJ3uqm5cDjfigN"
access_key = "551635264-RD3WtUx9Wh0I4vAnF0zKsfvHPfAFOAfBvCrpYKt6"
access_secret = "qiZuc8Bf9HzbpdZ391dwiAz4cXEMwISnRP3suNo3f7uW9"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)


bot_screen_names =[]
f = open('bots_data.csv','r',  encoding = "ISO-8859-1")
reader = csv.reader(f)

for row in reader:
   bot_screen_names.append(row[2])

f = open('bot_tweets.csv', 'w')
writer = csv.writer(f)
writer.writerow(["id","created_at","text"])

all_bots_tweets = []
new_bot_tweets = []

total = len(bot_screen_names)
print("Total number of screen_names: ", total)
j = 0

for i in bot_screen_names:
    
    
    try:
        new_bot_tweets = api.user_timeline(screen_name = i,count=200)
        j = j+1
        print (j)
        print("extracting "+ i + "tweets now!")
    except tweepy.error.TweepError:
         pass
    all_user_tweets.extend(new_user_tweets)
        
out_bots_tweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in all_bots_tweets]
writer.writerows(out_bots_tweets)
# Out:
# Total number of screen_names:  1057
# 1
# extracting mcgucket_bottweets now!
# 2
# extracting BowieK66tweets now!
# 3
# extracting ducknotepricetweets now!
# 4
# extracting robotrecipestweets now!
# 5
# extracting everyumlauttweets now!
# 6
# extracting glossatorytweets now!
# 7
# extracting Fancypants6047tweets now!
# 8
# extracting Hedgehogizetweets now!
# 9
# extracting jamieph93986621tweets now!
# 10
# extracting NothemDonellatweets now!
# 11
# extracting pony_strategiestweets now!
# 12
# extracting imgconvostweets now!
# 13
# extracting StobbeKindratweets now!
# 14
# extracting cgagraphicstweets now!
# 15
# extracting ngthaohuong97tweets now!
# 16
# extracting m_h_nishimuratweets now!
# 17
# extracting TheYearofLuigitweets now!
# 18
# extracting litpatches_txttweets now!
# 19
# extracting everysimiletweets now!
# 20
# extracting J_C_Christensentweets now!
# 21
# extracting DrPhilRxtweets now!
# 22
# extracting DivinaCooperitweets now!
# 23
# extracting libraryofemojitweets now!
# ...
