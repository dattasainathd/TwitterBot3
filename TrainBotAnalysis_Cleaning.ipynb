# %%
import pandas as pd
import numpy as np
from sklearn.metrics import *
path_to_insults = '/Users/dattasainathd/Downloads/'
data2 = pd.read_csv(path_to_insults + 'final_train_bot.csv',na_values='0', encoding = "ISO-8859-1", nrows = 1320)
data2['Value'] = 1
data2['bot'] = 1
data2 = data2.drop('created_at', axis=1)
data2.verified=data2.verified.astype(int)
data2.default_profile=data2.default_profile.astype(int)
data2.default_profile_image=data2.default_profile_image.astype(int)

data2 = data2.drop('status', axis=1)
data2 = data2.drop('id', axis=1)
data2 = data2.drop('id_str', axis=1)
data2 = data2.drop('url', axis=1)
#data2 = data2[data2.verified != 1]
data2 = data2.drop('has_extended_profile', axis=1)

data2.location.fillna('', inplace=True)
data2.description.fillna('', inplace=True)
data2.followers_count.fillna(0, inplace=True)
data2.friends_count.fillna(0, inplace=True)
data2.listedcount.fillna(0, inplace=True)
data2.statuses_count.fillna(0, inplace=True)
data2.favourites_count.fillna(0, inplace=True)
data2.followers_count=data2.followers_count.astype(int)

print("Did all the necessary changes for the data for manipulation")
# Out:
# Did all the necessary changes for the data for manipulation

# %%
data2
# Out:
#             screen_name                        location  \
# 0      "HoustonPokeMap"                   "Houston, TX"
# 1             kernyeahx       Templeville town, MD, USA
# 2       mattlieberisbot
# 3             sc_papers
# 4          lucarivera16           Dublin, United States
# 5        dantheimprover                      Austin, TX
# 6           _all_of_us_                   in a machine.
# 7         KatamariItems
# 8       AutophagyPapers
# 9            HSC_papers
# 10          everycheese                     cheese land
# 11           gyr_papers
# 12          lavon_court
# 13          AjstyleAlen
# 14          Rupesh93505
# 15         hard_to_yelp
# 16      fuckeverywordza
# 17      yeahTonyaGonzal                  Pensacola, USA
# 18              BbbbggU    _._______________, _________
# 19      ecin_gnihtaseod
# 20         tofu_product
# 21       onetruewiseman                         AMERICA
# 22        everycolorbot             the RGB color space
# 23         himawari8bot                           Space
# 24         emoji__polls                  â°Ã·Ââ¢Ã¼Â
# 25      everytrolltroll
# 26             hyphizer                        #botALLY
# 27        GreenwadeGema
# 28           par_papers
# 29       everyMTGlegend   The Coast Where Wizards Chill
# ...                 ...                             ...
# 1290          _blackobs
# 1291         NDM_Papers
# 1292     "AnayaJarrett"                              ""
# 1293    edgetics_papers
# 1294       everyailment            Your Doctor's Office
# 1295     ExtinctCatalog                           Earth
# 1296      GenerateAFace
# 1297    penguinandhouse
# 1298             badpng
# 1299        MIreilled28  Pacific Junction city, IA, USA
# 1300            NAS6222
# 1301           GWAS_lit   University of Sussex, England
# 1302    heyheyhayleighh
# 1303         SteemCodes
# 1304   "HendersonPkmon"                 "Henderson, NV"
# 1305           MenDoing                      Everywhere
# 1306         wendyc_bot
# 1307  "IndyPokeAlertDT"              "Indianapolis, IN"
# 1308      letsplaysnake
# 1309      NoellaKarlson
# 1310     "FtWorthPokes"                "Fort Worth, TX"
# 1311         "ishnobop"                              ""
# 1312       arpeggio_bot                     Up and down
# 1313          IanMaksin                      Chicago IL
# 1314        imgshredder
# 1315    darndesttruisms
# 1316       emojitoemoji
# 1317      gridgenerator
# 1318      moltar_ebooks
# 1319       DCell_papers                      Manchester
#
#                                             description  followers_count  \
# 0     "Rare and strong PokÅ½mon in Houston, TX. See ...             1291
# 1     From late 2014 Socium Marketplace will make sh...                1
# 2     Inspired by the smart, funny folks at @replyal...             1086
# 3                                                                     33
# 4                Inspiring cooks everywhere since 1956.               11
# 5     Just a guy trying to do good by telling everyo...                1
# 6                                       bot by @rubicon              193
# 7     [Bot rolled up by @BeachEpisode] Cataloguing e...             8227
# 8     Twitterbot for #Autophagy papers. Curated by @...              275
# 9                                                                     51
# 10    cheese cheese cheese // updates every 4 hours ...               51
# 11    Literature bot searching arXiv, biorXiv, PeerJ...                2
# 12                                                                     0
# 13                                                                     1
# 14                                                                     0
# 15                                                                   109
# 16    Why wait until 2020 for the Z's? Fucking every...              250
# 17             Musician, vegan, animal rights activist.               15
# 18                                          _______ XXX              190
# 19    straight-up rip-off of @doesathing_nice, excep...              181
# 20    Follow me to chat. // Reflecting your personal...            10175
# 21    The Truest Wisdom (aka trying to make even les...               23
# 22    colors.  all of 'em. | developed by @vogon; fe...           106126
# 23    Unofficial; imagery courtesy: Japan Meteorolog...             2302
# 24    A silly bot by @fourtonfish @botwikidotorg. Im...              443
# 25    exposing the BLATANT HYPOCRISY of @everycanont...               27
# 26        New words, from time to time. By @derekarnold              191
# 27                                                 secr                1
# 28    Twitterbot of #Parasitology papers in PubMed, ...              651
# 29    tweeting every legendary MTG card (as of 10/20...               37
# ...                                                 ...              ...
# 1290  Broadcasting live from covert surveillance cam...               82
# 1291  RSS feed from PubMed, that shows the most rece...               87
# 1292                                                 ""                3
# 1293  New papers using the Vidal lab's interactome '...               11
# 1294  Tweeting every code in the ICD-10-CM. A bot by...              260
# 1295  Every hour I'll tweet 1 of the 22482 species t...              291
# 1296  I'm just your average procedural avatar genera...              159
# 1297  A penguin and random houses. A publishing indu...               40
# 1298  PNG re-encoder. Message me images. I like line...             1814
# 1299  Father. Writer. Producer. Actively seeking to ...                0
# 1300                                                                   0
# 1301  Publication alert for genome-wide association ...              806
# 1302      FOLLOW @devonxxbt AND RETWEET/LIKE HER PINNED               25
# 1303  These might be Steam codes, but they probably ...               77
# 1304        "Henderson and Boulder City Pokemon Alerts"              140
# 1305  Chronicling men doing things. // A bot by @tin...               41
# 1306  A bot that tweets every line said by Wendy Cor...             1248
# 1307                "Alerts for Downtown Indianapolis."              662
# 1308  Play with mentions by including either droite/...               49
# 1309                              Anak Auhn Rmbulan A2R                0
# 1310  "24/7 Rare spawns for the fort worth area!\nDo...             1148
# 1311  "Hi, I don't care about pronouns call me whate...                2
# 1312  I tweet random arpeggios. My friend @mididitty...               19
# 1313  Creating a new blend of #classical, #jazz, #ro...            10057
# 1314  I redact, shred, and reassemble images you sen...             1464
# 1315  a bot by @_k_e_l_s_e_y, inspired by @theshrill...              490
# 1316  a bot by @inky // source: https://t.co/MJyd6NkYaf               93
# 1317  Simple generated grids three times a day. bot ...               36
# 1318                                                                  60
# 1319  Journal paper feed for academics interested in...              214
#
#       friends_count  listedcount  favourites_count  verified  statuses_count  \
# 0               0.0         10.0               0.0         0         78554.0
# 1             349.0          0.0              38.0         0            31.0
# 2               0.0         14.0               0.0         0           713.0
# 3               0.0          8.0               0.0         0           676.0
# 4             745.0          0.0             146.0         0           185.0
# 5             186.0          0.0               0.0         0            11.0
# 6               0.0         19.0               0.0         0          6068.0
# 7               2.0         89.0              26.0         0          2597.0
# 8               0.0         17.0              23.0         0          9922.0
# 9               3.0          9.0               0.0         0          2515.0
# 10              1.0         12.0               0.0         0           111.0
# 11              1.0          4.0               0.0         0           230.0
# 12             29.0          0.0               0.0         0             0.0
# 13            206.0          0.0               0.0         0             0.0
# 14             38.0          0.0               0.0         0             0.0
# 15              0.0         16.0               0.0         0         16067.0
# 16              0.0         25.0               0.0         0         31721.0
# 17           1941.0          1.0             319.0         0           406.0
# 18           1899.0          0.0              27.0         0             0.0
# 19              0.0         24.0               0.0         0         21506.0
# 20          11465.0        199.0             328.0         0         65022.0
# 21              4.0          8.0               4.0         0          6230.0
# 22              0.0        999.0               2.0         0         30156.0
# 23              3.0        161.0               4.0         0          7640.0
# 24              2.0         17.0               6.0         0          9584.0
# 25              1.0         10.0               0.0         0           145.0
# 26              2.0         19.0               0.0         0          5684.0
# 27             35.0          1.0              54.0         0            82.0
# 28              0.0         36.0               0.0         0         19867.0
# 29             45.0          7.0               0.0         0           191.0
# ...             ...          ...               ...       ...             ...
# 1290            0.0          9.0               0.0         0          4591.0
# 1291            0.0          9.0               0.0         0          2905.0
# 1292           21.0          0.0               0.0         0             0.0
# 1293            0.0          6.0               0.0         0            52.0
# 1294            0.0         34.0               0.0         0         25155.0
# 1295            1.0         17.0              30.0         0          3223.0
# 1296            6.0         26.0               0.0         0          5019.0
# 1297            0.0         15.0               0.0         0          3921.0
# 1298            0.0        172.0            5106.0         0         57061.0
# 1299          280.0          0.0              21.0         0            31.0
# 1300            9.0          0.0               0.0         0             0.0
# 1301           85.0         32.0             229.0         0          1497.0
# 1302          524.0          0.0               1.0         0             1.0
# 1303            1.0         27.0               0.0         0          5057.0
# 1304            0.0          2.0               0.0         0         16203.0
# 1305            0.0         12.0               0.0         0          2397.0
# 1306            7.0          3.0               0.0         0         11708.0
# 1307            3.0          6.0              60.0         0         29818.0
# 1308            1.0          6.0              23.0         0          9820.0
# 1309           35.0          0.0              58.0         0            83.0
# 1310            7.0         12.0               6.0         0         24607.0
# 1311           85.0          0.0               7.0         0            11.0
# 1312           23.0          4.0               2.0         0          2768.0
# 1313         7468.0        108.0            1905.0         0          1459.0
# 1314           40.0        157.0             996.0         0        144584.0
# 1315            1.0         21.0               0.0         0           927.0
# 1316            0.0         24.0               0.0         0          5145.0
# 1317            1.0         11.0               0.0         0           793.0
# 1318           32.0          6.0               2.0         0          4365.0
# 1319            0.0         20.0               0.0         0          9727.0
#
#        lang  default_profile  default_profile_image                    name  \
# 0      "en"                1                      0   "Houston PokÅ½ Alert"
# 1        en                1                      0             Keri Nelson
# 2        en                1                      0      Matt Lieber Is Bot
# 3        en                1                      1      single cell papers
# 4        en                0                      0            lucarivera16
# 5        en                1                      0          dantheimprover
# 6        en                0                      0       everything always
# 7        en                1                      0     Katamari Collection
# 8        en                0                      0        Autophagy Papers
# 9        en                1                      0           Hematopoiesis
# 10       en                0                      0       all of the cheese
# 11       en                1                      1               gyrpapers
# 12       en                1                      1             Lavon Court
# 13       en                1                      1               Alen Alex
# 14       en                1                      1        Rajesh prajapati
# 15       en                1                      0       how hard is it to
# 16       en                1                      0     fuck every word z-a
# 17       en                0                      0         yeahTonyaGonzal
# 18       th                1                      1                     xXx
# 19       en                1                      1       âÂÆÃâ¡Â«Ã¤u
# 20       en                1                      0                    tofu
# 21       en                0                      0       One True Wise Man
# 22       en                1                      0             Every Color
# 23       en                0                      0            himawari8bot
# 24       en                0                      0            EMOJI POLLS!
# 25       en                1                      0    EveryCanonTrollTroll
# 26       en                0                      0                hyphizer
# 27       en                1                      0          Gema Greenwade
# 28       en                0                      0     Parasitology papers
# 29       en                0                      0        every MTG legend
# ...     ...              ...                    ...                     ...
# 1290     en                0                      0                blackobs
# 1291     en                0                      0               NDMPapers
# 1292   "en"                1                      1               "kassanj"
# 1293     en                1                      0         Edgetics papers
# 1294     en                1                      0           Every Ailment
# 1295     en                0                      0      Extinction Catalog
# 1296     en                1                      0    Procedural AvatarBot
# 1297     en                1                      0       Penguin and House
# 1298     en                1                      0              badpng bot
# 1299     en                1                      0             MIreilled28
# 1300     en                1                      1              Nick Smith
# 1301  en-gb                0                      0                GWAS_lit
# 1302     en                1                      0                 BIO PLS
# 1303     en                1                      0             Steem Codes
# 1304   "en"                1                      0  "Henderson Poke Alert"
# 1305     en                0                      0        Men Doing Things
# 1306     en                0                      0      Wendy Corduroy bot
# 1307   "en"                1                      0       "IndyPokeAlertDT"
# 1308     fr                0                      0        Let's play Snake
# 1309     en                1                      0          Noella Karlson
# 1310   "en"                1                      0              "ft worth"
# 1311   "en"                1                      1                  "Kell"
# 1312     en                0                      0            Arpeggio Bot
# 1313     en                0                      0              Ian Maksin
# 1314     en                0                      0            Img Shredder
# 1315     en                1                      0              baby jenny
# 1316     en                0                      0        [face] to [face]
# 1317     en                1                      0       grids grids grids
# 1318     en                1                      0           MOLTAR EBOOKS
# 1319     en                1                      0         Dendritic cells
#
#       bot  Value
# 0       1      1
# 1       1      1
# 2       1      1
# 3       1      1
# 4       1      1
# 5       1      1
# 6       1      1
# 7       1      1
# 8       1      1
# 9       1      1
# 10      1      1
# 11      1      1
# 12      1      1
# 13      1      1
# 14      1      1
# 15      1      1
# 16      1      1
# 17      1      1
# 18      1      1
# 19      1      1
# 20      1      1
# 21      1      1
# 22      1      1
# 23      1      1
# 24      1      1
# 25      1      1
# 26      1      1
# 27      1      1
# 28      1      1
# 29      1      1
# ...   ...    ...
# 1290    1      1
# 1291    1      1
# 1292    1      1
# 1293    1      1
# 1294    1      1
# 1295    1      1
# 1296    1      1
# 1297    1      1
# 1298    1      1
# 1299    1      1
# 1300    1      1
# 1301    1      1
# 1302    1      1
# 1303    1      1
# 1304    1      1
# 1305    1      1
# 1306    1      1
# 1307    1      1
# 1308    1      1
# 1309    1      1
# 1310    1      1
# 1311    1      1
# 1312    1      1
# 1313    1      1
# 1314    1      1
# 1315    1      1
# 1316    1      1
# 1317    1      1
# 1318    1      1
# 1319    1      1
#
# [1320 rows x 15 columns]

# %%
data_description = data2['description'].str.lower()
data_name = data2['name'].str.lower()
data_screen_name = data2['screen_name'].str.lower()
bot = 'bot'
count = 0
serial = -1
for x in data_screen_name:
    serial = serial + 1
    if bot in x:
        data2.ix[serial, 'Value'] = 2
        count += 1
serial = -1

for x in data_name:
    serial = serial + 1
    try:
        if bot in x:
            data2.ix[serial, 'Value'] = 2
            count += 1
    except:
        pass

serial = -1

for x in data_description:
    serial = serial + 1
    try:
        if bot in x:
            data2.ix[serial, 'Value'] = 2
            count += 1
    except:
        pass

print("trying to search for 'bot' in names, screen_names & description")
print("if existed, we shall change value to 2")
print(count)
#trying to remove accounts with zero followers/zero friends/zero tweets
#Bias obtained from given data
serial = -1
count = 0
unnec = []
for x in range(0, 1477):
    try:
        serial = serial + 1
        if(data2.loc[serial, 'Value']==1):
            if(data2.loc[serial, 'statuses_count']==0 or data2.loc[serial, 'followers_count']==0 or 
               data2.loc[serial, 'friends_count']==0 ):
                data2.loc[serial, 'Value'] = 3
                count+=1
    except:
        pass
print("trying to search for accounts with followers, friends or tweets in 0")
print("if there is some accounts like that we will consider them as 'starter' humans and assign value 3")
print(count)

#trying to filter accounts usually used by comman man (not celebrities or verified users)
serial = -1
count = 0
unnec = []
for x in range(0, 1477):
    try:
        serial = serial + 1
        if(data2.loc[serial, 'Value']==1):
            if((data2.loc[serial, 'statuses_count']/data2.loc[serial, 'followers_count']<12 
                or data2.loc[serial, 'statuses_count']/data2.loc[serial, 'friends_count']<12)):
                data2.loc[serial, 'Value'] = 3
                count+= 1
    except:
        pass
print("trying to filter accounts usually used by comman man (not celebrities or verified users)")
print("comman users have low tweet/following or tweet/friends and assigned value 3")
print(count)

#trying to filter accounts which are verified all the verified user accounts are humans
#because twitter verifies users only 
serial = -1
count = 0
unnec = []
for x in range(0, 1477):
    try:
        serial = serial + 1
        if(data2.loc[serial, 'verified']==1):
            data2.loc[serial, 'Value'] = 3
            count+= 1
    except:
        pass
print("trying to filter accounts which are verified all the verified user accounts are humans")
print("twitter user accounts which are verified are assigned to value 3")
print(count)

#there might be some clever bots who dont have any description but follow huge number of poeople or they are followed
#by huge number.
serial = -1
count = 0
unnec = []
for x in range(0, 1477):
    try:
        serial = serial + 1
        if(data2.loc[serial, 'Value']==1):
            if((data2.loc[serial, 'statuses_count']/data2.loc[serial, 'followers_count']>10 )
                or (data2.loc[serial, 'statuses_count']/data2.loc[serial, 'friends_count']>10)):
                data2.loc[serial, 'Value'] = 2
                count+= 1
    except:
        pass
print("huge tweeting accounts")
print("huge rate tweet accounts are considered bots and retained values 2")
print(count)
# Out:
# trying to search for 'bot' in names, screen_names & description
# if existed, we shall change value to 2
# 799
# trying to search for accounts with followers, friends or tweets in 0
# if there is some accounts like that we will consider them as 'starter' humans and assign value 3
# 253
# trying to filter accounts usually used by comman man (not celebrities or verified users)
# comman users have low tweet/following or tweet/friends and assigned value 3
# 424
# trying to filter accounts which are verified all the verified user accounts are humans
# twitter user accounts which are verified are assigned to value 3
# 8
# huge tweeting accounts
# huge rate tweet accounts are considered bots and retained values 2
# 156

# %%
serial = -1
count = 0
unnec = []
for x in range(0, 1477):
    try:
        serial = serial + 1
        if(data2.loc[serial, 'Value']==3):
            data2.loc[serial, 'Value'] = 0
        else:
            data2.loc[serial, 'Value'] = 1
        count+= 1
    except:
        pass
count
# Out:
# 1320

# %%
data_value = data2['Value']
datafinal = data2['bot']
print("Accuracy Score: ", (accuracy_score(datafinal, data_value)))
cnf_matrix = confusion_matrix(datafinal, data_value)
print("Confusion Matrix:")
print(cnf_matrix)
# Out:
# Accuracy Score:  0.487121212121
# Confusion Matrix:
# [[  0   0]
#  [677 643]]

# %%
data3 = data2[data2.Value != 0]

# %%
data3
# Out:
#             screen_name                location  \
# 2       mattlieberisbot
# 6           _all_of_us_           in a machine.
# 7         KatamariItems
# 8       AutophagyPapers
# 9            HSC_papers
# 11           gyr_papers
# 19      ecin_gnihtaseod
# 21       onetruewiseman                 AMERICA
# 22        everycolorbot     the RGB color space
# 23         himawari8bot                   Space
# 24         emoji__polls          â°Ã·Ââ¢Ã¼Â
# 26             hyphizer                #botALLY
# 28           par_papers
# 30      assembly_papers
# 31        DeepDreamThis         London, England
# 34      dstroyeveryword
# 36      snowcloneminute
# 37        NESGarbageBot
# 38       BklynMuseumBot            Brooklyn, NY
# 39           clitoscope
# 40             feud_exe
# 41            vaporfave
# 45         AttentiveBot  Tended to by @dphiffer
# 50         CrisprPhages
# 51            forestgen         soothing forest
# 53              rnomics                  France
# 55          DiGRAThemes                Snowbird
# 58       super_jeopardy
# 59           Speed_1994         LA, FIRST TIME!
# 61         everywordNYT
# ...                 ...                     ...
# 1258       JustToSayBot              the icebox
# 1262           EveryGem
# 1263           yayfrens              All around
# 1267      AestheticDril
# 1270       AndromedaBot
# 1271      TheRiddlerBot       Coimbra, Portugal
# 1272         TINYiPhone
# 1274    metagenomic_lit              Microbiome
# 1275     freezeframebot
# 1277             cihpom                   Earth
# 1278    AllTheLanguages
# 1281           EcoLog_L
# 1282      LinkRelations
# 1287     KareninaClones      _Ã__âÂ_Â¼___Â¡
# 1289         litscraper
# 1294       everyailment    Your Doctor's Office
# 1296      GenerateAFace
# 1298             badpng
# 1303         SteemCodes
# 1305           MenDoing              Everywhere
# 1306         wendyc_bot
# 1307  "IndyPokeAlertDT"      "Indianapolis, IN"
# 1308      letsplaysnake
# 1310     "FtWorthPokes"        "Fort Worth, TX"
# 1312       arpeggio_bot             Up and down
# 1314        imgshredder
# 1315    darndesttruisms
# 1316       emojitoemoji
# 1317      gridgenerator
# 1318      moltar_ebooks
#
#                                             description  followers_count  \
# 2     Inspired by the smart, funny folks at @replyal...             1086
# 6                                       bot by @rubicon              193
# 7     [Bot rolled up by @BeachEpisode] Cataloguing e...             8227
# 8     Twitterbot for #Autophagy papers. Curated by @...              275
# 9                                                                     51
# 11    Literature bot searching arXiv, biorXiv, PeerJ...                2
# 19    straight-up rip-off of @doesathing_nice, excep...              181
# 21    The Truest Wisdom (aka trying to make even les...               23
# 22    colors.  all of 'em. | developed by @vogon; fe...           106126
# 23    Unofficial; imagery courtesy: Japan Meteorolog...             2302
# 24    A silly bot by @fourtonfish @botwikidotorg. Im...              443
# 26        New words, from time to time. By @derekarnold              191
# 28    Twitterbot of #Parasitology papers in PubMed, ...              651
# 30                 Papers on directed and self assembly              331
# 31    Tweet me a picture and I'll #deepdream it for ...             1327
# 34    Destroy every word in the english language. Ta...             4247
# 36    A mashup of http://t.co/Tdj0YYLDOM and http://...              163
# 37    Tweets randomly-generated 16x16 images using t...               32
# 38    I am a bot that tweets one random object from ...              903
# 39    A compendium of newly discovered species of cl...              108
# 40                          Name something by @irondavy              190
# 41    Tweets ~10 times a day between 8am-10pm PST. W...              675
# 45    You may have missed some things, I will help y...              399
# 50    A twitterbot posting the latest pubmed publica...               36
# 51    tweet me to get your own unique peaceful fores...                8
# 53    #RNomics, #RNA biology, RNA #bioinformatics, #...             1807
# 55           DiGRA 2014 Theme Generator. // by @ibogost               82
# 58    This! Is! Jeopardy! I'm your host Alex Trebek ...               78
# 59                                    with love by @ems              403
# 61    All the news that fit in @everyword. Tribute b...               68
# ...                                                 ...              ...
# 1258  you were probably saving them for breakfast. s...             1461
# 1262  Looking for the hidden gems among @everyword's...               41
# 1263  Hello! I am a loving friend bot! @mossdogmusic...             5418
# 1267  @dril's tweets, but for your home or office. A...              904
# 1270  Exploring Hubble's largest photo (69536x22230p...             3588
# 1271  Solve the riddle by replying only the name of ...              132
# 1272  Automatic follow back account. Will automatica...             3788
# 1274  I'm a bot Tweeting newly published papers on m...              883
# 1275  *record scratch* *freeze frame* You might be w...             3835
# 1277                                                                  78
# 1278  Tweeting all the languages. All of them. Proce...              235
# 1281  Bot that autotweets EcoLog-L posts. Not associ...             2845
# 1282  Follow me for information on the hottest new I...               52
# 1287  Happy bots are all alike; every unhappy bot is...               10
# 1289                                                                  78
# 1294  Tweeting every code in the ICD-10-CM. A bot by...              260
# 1296  I'm just your average procedural avatar genera...              159
# 1298  PNG re-encoder. Message me images. I like line...             1814
# 1303  These might be Steam codes, but they probably ...               77
# 1305  Chronicling men doing things. // A bot by @tin...               41
# 1306  A bot that tweets every line said by Wendy Cor...             1248
# 1307                "Alerts for Downtown Indianapolis."              662
# 1308  Play with mentions by including either droite/...               49
# 1310  "24/7 Rare spawns for the fort worth area!\nDo...             1148
# 1312  I tweet random arpeggios. My friend @mididitty...               19
# 1314  I redact, shred, and reassemble images you sen...             1464
# 1315  a bot by @_k_e_l_s_e_y, inspired by @theshrill...              490
# 1316  a bot by @inky // source: https://t.co/MJyd6NkYaf               93
# 1317  Simple generated grids three times a day. bot ...               36
# 1318                                                                  60
#
#       friends_count  listedcount  favourites_count  verified  statuses_count  \
# 2               0.0         14.0               0.0         0           713.0
# 6               0.0         19.0               0.0         0          6068.0
# 7               2.0         89.0              26.0         0          2597.0
# 8               0.0         17.0              23.0         0          9922.0
# 9               3.0          9.0               0.0         0          2515.0
# 11              1.0          4.0               0.0         0           230.0
# 19              0.0         24.0               0.0         0         21506.0
# 21              4.0          8.0               4.0         0          6230.0
# 22              0.0        999.0               2.0         0         30156.0
# 23              3.0        161.0               4.0         0          7640.0
# 24              2.0         17.0               6.0         0          9584.0
# 26              2.0         19.0               0.0         0          5684.0
# 28              0.0         36.0               0.0         0         19867.0
# 30             56.0         36.0              23.0         0         29989.0
# 31              2.0         92.0               0.0         0         24199.0
# 34              2.0         72.0             587.0         0        109325.0
# 36              2.0         74.0              64.0         0        552492.0
# 37              1.0         12.0               0.0         0          6181.0
# 38              1.0         50.0               0.0         0          3654.0
# 39             10.0          9.0              10.0         0           537.0
# 40              1.0         23.0               1.0         0          4032.0
# 41            118.0         66.0               8.0         0         15437.0
# 45            679.0         20.0              64.0         0         26073.0
# 50              1.0          6.0               0.0         0           510.0
# 51              1.0          1.0               0.0         0            29.0
# 53            101.0        258.0             124.0         0        125403.0
# 55             49.0         10.0               0.0         0         16728.0
# 58              1.0         14.0               0.0         0          4438.0
# 59              6.0         16.0               1.0         0         12395.0
# 61              0.0         15.0               1.0         0         25193.0
# ...             ...          ...               ...       ...             ...
# 1258          197.0        134.0               1.0         0         23533.0
# 1262            0.0         11.0               0.0         0           300.0
# 1263         4307.0         97.0               1.0         0         45675.0
# 1267            0.0         19.0               0.0         0          1123.0
# 1270            0.0        135.0               0.0         0         18413.0
# 1271           46.0         24.0             740.0         0          7346.0
# 1272         4466.0         41.0               3.0         0        297198.0
# 1274            1.0         42.0               0.0         0          2574.0
# 1275            1.0         77.0               1.0         0          1432.0
# 1277           41.0          0.0            6628.0         0          4249.0
# 1278          192.0          9.0               4.0         0          7875.0
# 1281            4.0         62.0               0.0         0         16272.0
# 1282            1.0         10.0               0.0         0            80.0
# 1287            2.0          4.0               0.0         0          5775.0
# 1289            0.0         31.0               0.0         0         10130.0
# 1294            0.0         34.0               0.0         0         25155.0
# 1296            6.0         26.0               0.0         0          5019.0
# 1298            0.0        172.0            5106.0         0         57061.0
# 1303            1.0         27.0               0.0         0          5057.0
# 1305            0.0         12.0               0.0         0          2397.0
# 1306            7.0          3.0               0.0         0         11708.0
# 1307            3.0          6.0              60.0         0         29818.0
# 1308            1.0          6.0              23.0         0          9820.0
# 1310            7.0         12.0               6.0         0         24607.0
# 1312           23.0          4.0               2.0         0          2768.0
# 1314           40.0        157.0             996.0         0        144584.0
# 1315            1.0         21.0               0.0         0           927.0
# 1316            0.0         24.0               0.0         0          5145.0
# 1317            1.0         11.0               0.0         0           793.0
# 1318           32.0          6.0               2.0         0          4365.0
#
#       lang  default_profile  default_profile_image                     name  \
# 2       en                1                      0       Matt Lieber Is Bot
# 6       en                0                      0        everything always
# 7       en                1                      0      Katamari Collection
# 8       en                0                      0         Autophagy Papers
# 9       en                1                      0            Hematopoiesis
# 11      en                1                      1                gyrpapers
# 19      en                1                      1        âÂÆÃâ¡Â«Ã¤u
# 21      en                0                      0        One True Wise Man
# 22      en                1                      0              Every Color
# 23      en                0                      0             himawari8bot
# 24      en                0                      0             EMOJI POLLS!
# 26      en                0                      0                 hyphizer
# 28      en                0                      0      Parasitology papers
# 30      en                1                      0           assemblypapers
# 31      en                1                      0          Deep Dream This
# 34      en                0                      0       destroy every word
# 36      en                1                      0       Snowclone-a-Minute
# 37      en                1                      0          NES Garbage Bot
# 38      en                0                      0      Brooklyn Museum Bot
# 39      en                0                      0        Clitoris Vulgaris
# 40      en                0                      0              Survey Says
# 41      en                0                      0                Vaporfave
# 45      en                0                      0             AttentiveBot
# 50      en                1                      1         Phages & Crisprs
# 51      en                0                      0      peaceful forest bot
# 53      en                0                      0          Fabrice Leclerc
# 55      en                0                      0             DiGRA Themes
# 58      en                0                      0       Jeopardy! Stumpers
# 59      en                0                      0             Speed (1994)
# 61      en                1                      0             everywordNYT
# ...    ...              ...                    ...                      ...
# 1258    en                1                      0      This Is Just to Say
# 1262    en                1                      0                Every Gem
# 1263    en                0                      0             Yayfrens Bot
# 1267    en                0                      0           Aesthetic Dril
# 1270    en                0                      0  â°ÃÃ¼Andromedaâ°ÃÃ¼
# 1271    en                1                      0            TheRiddlerBot
# 1272    en                1                      0                     Siri
# 1274    en                1                      0      Metagenomics Papers
# 1275    en                1                      0         Freeze Frame Bot
# 1277    en                1                      0                       __
# 1278    en                1                      0        All The Languages
# 1281    en                0                      0                 EcoLog-L
# 1282    en                1                      0           Link Relations
# 1287    en                1                      0          Karenina Clones
# 1289    en                1                      0           Literature Bot
# 1294    en                1                      0            Every Ailment
# 1296    en                1                      0     Procedural AvatarBot
# 1298    en                1                      0               badpng bot
# 1303    en                1                      0              Steem Codes
# 1305    en                0                      0         Men Doing Things
# 1306    en                0                      0       Wendy Corduroy bot
# 1307  "en"                1                      0        "IndyPokeAlertDT"
# 1308    fr                0                      0         Let's play Snake
# 1310  "en"                1                      0               "ft worth"
# 1312    en                0                      0             Arpeggio Bot
# 1314    en                0                      0             Img Shredder
# 1315    en                1                      0               baby jenny
# 1316    en                0                      0         [face] to [face]
# 1317    en                1                      0        grids grids grids
# 1318    en                1                      0            MOLTAR EBOOKS
#
#       bot  Value
# 2       1      1
# 6       1      1
# 7       1      1
# 8       1      1
# 9       1      1
# 11      1      1
# 19      1      1
# 21      1      1
# 22      1      1
# 23      1      1
# 24      1      1
# 26      1      1
# 28      1      1
# 30      1      1
# 31      1      1
# 34      1      1
# 36      1      1
# 37      1      1
# 38      1      1
# 39      1      1
# 40      1      1
# 41      1      1
# 45      1      1
# 50      1      1
# 51      1      1
# 53      1      1
# 55      1      1
# 58      1      1
# 59      1      1
# 61      1      1
# ...   ...    ...
# 1258    1      1
# 1262    1      1
# 1263    1      1
# 1267    1      1
# 1270    1      1
# 1271    1      1
# 1272    1      1
# 1274    1      1
# 1275    1      1
# 1277    1      1
# 1278    1      1
# 1281    1      1
# 1282    1      1
# 1287    1      1
# 1289    1      1
# 1294    1      1
# 1296    1      1
# 1298    1      1
# 1303    1      1
# 1305    1      1
# 1306    1      1
# 1307    1      1
# 1308    1      1
# 1310    1      1
# 1312    1      1
# 1314    1      1
# 1315    1      1
# 1316    1      1
# 1317    1      1
# 1318    1      1
#
# [643 rows x 15 columns]

# %%
TP = 0
FP = 0
TN = 0
FN = 0

for i in range(len(data_value)): 
    if datafinal[i]==data_value[i]==1:
        TP += 1
        #print(i)
for i in range(len(data_value)): 
    if data_value[i]==1 and datafinal[i]!=data_value[i]:
        FP += 1
        #print(i)
for i in range(len(data_value)): 
    if datafinal[i]==data_value[i]==0:
        TN += 1
        #print(i)
for i in range(len(data_value)): 
    if data_value[i]==0 and datafinal[i]!=data_value[i]:
        FN += 1
        #print(i)
