# %%
import tweepy
import csv
import time
import pandas

consumer_key = "BYADovvYQhDt8YWSGw57HqcZO"
consumer_secret = "CbCfzNaGf7BuH5nTksUZUo7VWlnhJEkmOiKFqJ3uqm5cDjfigN"
access_key = "551635264-RD3WtUx9Wh0I4vAnF0zKsfvHPfAFOAfBvCrpYKt6"
access_secret = "qiZuc8Bf9HzbpdZ391dwiAz4cXEMwISnRP3suNo3f7uW9"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)


user_screen_names =[]
f = open('nonbots_data.csv','r',  encoding = "ISO-8859-1")
reader = csv.reader(f)

for row in reader:
   user_screen_names.append(row[2])

f = open('users_tweets.csv', 'w')
writer = csv.writer(f)
writer.writerow(["id","created_at","text"])

all_users_tweets = []
new_user_tweets = []

total = len(user_screen_names)
print("Total number of screen_names: ", total)
j = 0

for i in user_screen_names:
    try:
        new_user_tweets = api.user_timeline(screen_name = i,count=200)
        j = j+1
        print (j)
        print("extracting "+ i + "tweets now!")
    except tweepy.error.TweepError:
         pass
    all_users_tweets.extend(new_user_tweets)
        
out_users_tweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in all_users_tweets]
writer.writerows(out_users_tweets)
# Out:
# Total number of screen_names:  1177
# 1
# extracting JameYu7tweets now!
# 2
# extracting Residentetweets now!
# 3
# extracting cameronbrighttweets now!
# 4
# extracting eva_recinostweets now!
# 5
# extracting Paula_Deentweets now!
# 6
# extracting MatthewDaddonatweets now!
# 7
# extracting CameronNewtontweets now!
# 8
# extracting umar_burneytweets now!
# 9
# extracting jennykijowskitweets now!
# 10
# extracting Shoham_11tweets now!
# 11
# extracting anthonyedwardstweets now!
# 12
# extracting kayivelissetweets now!
# 13
# extracting lightstweets now!
# 14
# extracting sachin_rttweets now!
# 15
# extracting RyanSeacresttweets now!
# 16
# extracting AdamAWanderertweets now!
# 17
# extracting voiceofskylertweets now!
# 18
# extracting Kenny_Maynetweets now!
# 19
# extracting catherinedwyertweets now!
# 20
# extracting Mc_Drivertweets now!
# 21
# extracting IzzieStark99tweets now!
# 22
# extracting ilkinhasanov89tweets now!
# 23
# extracting CharlizeAfricatweets now!
# 24
# ...
